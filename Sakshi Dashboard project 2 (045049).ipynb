# %% [markdown]
# # SETTING UP DATA

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_excel('covid 19.xlsx')    # reading the data from the file
data     #printing the data
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
data.describe()  #Generate descriptive statistics of the given data
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# ...

# %%
data.head()   #Top 5 Rows
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
data.tail()     # Bottom 5 Rows
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 182           2              0                0.73                  35.33
# 183           0              0               10.00                  80.00
# 184           4             36               28.56                  49.26
# 185           1            465                3.08                  61.84
# 186           2             24                1.33                  20.04
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
data.shape      #Tuple of array dimensions
# Out:
# (187, 15)

# %%
data.ndim      #Number of array dimensions
# Out:
# 2

# %%
data.index    # Range Index of the given data
# Out:
# RangeIndex(start=0, stop=187, step=1)

# %%
data.columns     # List of all column names
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
a = data.sort_values('Confirmed', ascending = False).head()
for i,j in a[['Country/Region','Confirmed']].values:
    print(f"{i:<12}{j:>12}")
# Out:
# US               4290259
# Brazil           2442375
# India            1480073
# Russia            816680
# South Africa      452529

# %%
a = data.sort_values('Recovered / 100 Cases',ascending =False).head(10)
for i in a['Country/Region'].values:
           print(i)
# Out:
# Holy See
# Grenada
# Dominica
# Djibouti
# Iceland
# Brunei
# New Zealand
# Qatar
# Malaysia
# Mauritius

# %%
x = data['WHO Region'].unique()
for i in x:
    mask = data['WHO Region'] == i
    a =data[mask]['Confirmed'].sum()
    print(f"{i:<22}{a:>10}")
# Out:
# Eastern Mediterranean    1490744
# Europe                   3299523
# Africa                    723207
# Americas                 8839286
# Western Pacific           292428
# South-East Asia          1835297

# %%
a = data.sort_values('Active', ascending=False, ignore_index=True).head(1)
print(a['Country/Region'].values," - ",a['Active'].values)
# Out:
# ['US']  -  [2816444]

# %% [markdown]
# # DATA VISUALISATION

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x="WHO Region",data=data,order = data.groupby(by=['WHO Region']).count().index)
plt.title("Number of Country in each WHO Region")
plt.show()

# %%
sns.set_style("whitegrid")
labels = ['Europe', 'Africa', 'Americas','Eastern Mediterranean', 'Western Pacific', 'South-East Asia']
plt.figure(figsize=(8,6))
plt.pie(data['WHO Region'].value_counts(), labels = labels, autopct = '%.2f%%',pctdistance=0.8)
plt.title("Percentage of Cases in each WHO Region")
plt.show()

# %%
data.plot(x='WHO Region', y = 'New cases', figsize = (15,5))
# Out:
# <AxesSubplot:xlabel='WHO Region'>

# %%
a1 = data[data['WHO Region'] =='Eastern Mediterranean']['Recovered'].sum()
a2 = data[data['WHO Region'] =='Europe']['Recovered'].sum()
a3 = data[data['WHO Region'] =='Africa']['Recovered'].sum()
a4 = data[data['WHO Region'] =='Americas']['Recovered'].sum()
a5 = data[data['WHO Region'] =='Western Pacific']['Recovered'].sum()
a6 = data[data['WHO Region'] =='South-East Asia']['Recovered'].sum()
x = [a1, a2, a3, a4, a5, a6]
labels = ['Eastern Mediterranean', 'Europe', 'Africa', 'Americas',
       'Western Pacific', 'South-East Asia']
plt.figure(figsize=(10,5))
plt.pie(x,labels = labels, autopct = '%.2f%%',pctdistance=0.8)
plt.title("Recovery Percentage of each WHO Region")
plt.show()

# %%
death = data['Deaths']
d1 = death[death<1000].count()
d2 =death[(death>=1000) & (death<2000)].count()
d3 =death[(death>=2000) & (death<4000)].count()
d4 =death[(death>=4000) & (death<6000)].count()
d5 =death[(death>=6000) & (death<8000)].count()
d6 =death[(death>=8000) & (death<10000)].count()
d7 =death[death>=10000].count()
x = ['<1000','1000-2000','2000-4000','4000-6000','6000-8000','8000-10000','10000 & above']
y = [d1,d2,d3,d4,d5,d6,d7]
plt.figure(figsize=(10,8))
sns.barplot(x=x, y=y)
plt.xlabel("Range")
plt.ylabel("Number of countries")
plt.title("Number of Deaths")
plt.show()

# %%
a1 = data[data['WHO Region'] =='Eastern Mediterranean']['Active'].sum()
a2 = data[data['WHO Region'] =='Europe']['Active'].sum()
a3 = data[data['WHO Region'] =='Africa']['Active'].sum()
a4 = data[data['WHO Region'] =='Americas']['Active'].sum()
a5 = data[data['WHO Region'] =='Western Pacific']['Active'].sum()
a6 = data[data['WHO Region'] =='South-East Asia']['Active'].sum()
y = [a1, a2, a3, a4, a5, a6]
x = ['Eastern Mediterranean', 'Europe', 'Africa', 'Americas',
       'Western Pacific', 'South-East Asia']
plt.figure(figsize=(10,8))
plt.barh(x, y)
for i,j in enumerate(y):
    plt.text(j,i,str(j))
plt.title("Region wise Active Cases")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x="WHO Region", y="New cases",data=data)
plt.title("Number of New Cases in each WHO Region")
plt.show()

# %%
pip install dash
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dash-html-components dash-core-components
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dash-bootstrap-components
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # SLICERS

# %%
import pandas as pd
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px

# Load the data
filename = "covid 19.xlsx"
df = pd.read_excel(filename)

# Initialize the Dash app
app = dash.Dash(__name__)

# Define the layout of the app
app.layout = html.Div([
    html.H1("COVID-19 Dashboard"),

    dcc.Dropdown(
        id='country-dropdown',
        options=[
            {'label': country, 'value': country} for country in df['Country/Region'].unique()
        ],
        value=df['Country/Region'].unique()[0],
        multi=False,
        style={'width': '50%'}
    ),

    dcc.Dropdown(
        id='region-slicer',
        options=[
            {'label': region, 'value': region} for region in df['WHO Region'].unique()
        ],
        value=df['WHO Region'].unique(),
        multi=True,
        style={'width': '50%'}
    ),

    dcc.Graph(id='confirmed-line-chart'),
    dcc.Graph(id='deaths-bar-chart'),
    dcc.Graph(id='recovered-pie-chart'),
    dcc.Graph(id='active-scatter-plot'),

    html.Div(id='selected-country-stats')
])

# Define callback to update charts and display statistics based on dropdown selection
@app.callback(
    [Output('confirmed-line-chart', 'figure'),
     Output('deaths-bar-chart', 'figure'),
     Output('recovered-pie-chart', 'figure'),
     Output('active-scatter-plot', 'figure'),
     Output('selected-country-stats', 'children')],
    [Input('country-dropdown', 'value'),
     Input('region-slicer', 'value')]
)
def update_charts_and_stats(selected_country, selected_regions):
    filtered_df = df[df['Country/Region'] == selected_country]
    filtered_df = filtered_df[filtered_df['WHO Region'].isin(selected_regions)]

    # Line Chart - Confirmed Cases Over Time
    confirmed_line_chart = px.line(
        filtered_df,
        x=filtered_df.index,
        y='Confirmed',
        line_group='Country/Region',
        color='Country/Region',
        labels={'Confirmed': 'Confirmed Cases'},
        title='Confirmed Cases Over Time'
    )

    # Bar Chart - Deaths
    deaths_bar_chart = {
        'data': [{'x': ['Confirmed', 'Deaths', 'Recovered', 'Active'],
                  'y': [filtered_df['Confirmed'].max(), filtered_df['Deaths'].max(), filtered_df['Recovered'].max(), filtered_df['Active'].max()],
                  'type': 'bar'}],
        'layout': {'title': 'COVID-19 Statistics'}
    }

    # Pie Chart - Recovered Percentage
    recovered_pie_chart = {
        'data': [{'labels': ['Active', 'Recovered'],
                  'values': [filtered_df['Active'].max(), filtered_df['Recovered'].max()],
                  'type': 'pie'}],
        'layout': {'title': 'Active vs Recovered Percentage'}
    }

    # Scatter Plot - 1 Week Change vs 1 Week % Increase
    active_scatter_plot = px.scatter(
        filtered_df,
        x='1 week change',
        y='1 week % increase',
        color='WHO Region',
        labels={'1 week change': '1 Week Change', '1 week % increase': '1 Week % Increase'},
        title='1 Week Change vs 1 Week % Increase'
    )

    selected_country_stats = f"Selected Country: {selected_country}, Total Confirmed: {filtered_df['Confirmed'].max()}, Total Deaths: {filtered_df['Deaths'].max()}, Total Recovered: {filtered_df['Recovered'].max()}"

    return confirmed_line_chart, deaths_bar_chart, recovered_pie_chart, active_scatter_plot, selected_country_stats

# Run the app
if __name__ == '__main__':
    app.run_server(port=8050, debug=True)
# Out:
# C:\Users\SAHIL MITTAL\AppData\Local\Temp/ipykernel_22512/3001087630.py:3: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# C:\Users\SAHIL MITTAL\AppData\Local\Temp/ipykernel_22512/3001087630.py:4: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22512/3001087630.py in <module>
#     102 # Run the app
#     103 if __name__ == '__main__':
# --> 104     app.run_server(port=8050, debug=True)
#
# ~\anaconda3\lib\site-packages\dash\dash.py in run_server(self, *args, **kwargs)
#    2173         See `app.run` for usage information.
# ...

# %% [markdown]
# # PROJECT REPORT

# %% [markdown]
# 1. ABOUT DATASET:
#    The COVID-19 dataset utilized in the provided code encompasses a diverse set of metrics characterizing the impact of the        pandemic across different countries and regions. Essential indicators include the total confirmed cases, deaths, and            recoveries, alongside additional insights such as new cases and regional classification by the World Health Organization        (WHO). The dataset facilitates a nuanced examination of the virus's progression, with features like 1-week changes and          percentage increases offering temporal perspectives. This comprehensive information empowers the creation of informative        visualizations and analytical tools to gain deeper insights into the evolving dynamics of the COVID-19 pandemic on a global      and regional scale.
#
# 2. OBJECTIVES :
#    The objective of creating the dashboard in the provided code is to visually represent and explore COVID-19 data in an            interactive and informative way which provides the following information:
#    a) Display the trend of confirmed COVID-19 cases over time for the selected country, providing an overview of the progression       of the pandemic.
#    b) Showcase key COVID-19 statistics for the selected country, including confirmed cases, deaths, recovered, and active cases.
#    c) Illustrate the percentage of active cases compared to recovered cases for the selected country, providing a quick snapshot       of the current status.
#    d) Explore the relationship between the 1-week change in confirmed cases and the percentage increase in cases for different         WHO regions, allowing for insights into the dynamics of the pandemic.
#    e) Show the total confirmed cases, deaths, and recovered cases for the selected country, giving users a quick summary of the       situation.
#    f) Allow users to interactively choose a specific country and filter data by WHO regions, enabling a personalized exploration       of COVID-19 data.
#
# 3. QUERIES :
#    a) Number of Countries in each WHO Region.
#    b) Percenatge of Cases in each WHO Region.
#    c) Number of Active Cases in each WHO Region.
#    d) Number of deaths in each WHO Region.
#    e) Recovery Percenatage in each WHO Region.
#    f) Number of New Cases in each WHO Region.
#
# 4. ANALYSIS AND INSIGHTS  :
#
#    1. BAR CHART SHOWING NUMBER OF COUNTRIES IN EACH WHO REGION :
#       The bar chart visually represents the distribution of the number of countries in each WHO region based on the given data.       The regions include Africa, Americas, Eastern Mediterranean, Europe, South-East Asia, and Western Pacific. The heights of       the bars correspond to the count of countries in each region.
#
#       ANALYSIS:
#       a) The bar chart shows that Europe has the largest number of countries among the specified WHO regions, with approximately          60 countries. This indicates a diverse landscape in terms of healthcare systems, public health challenges, and                  potentially different needs for healthcare interventions.
#       b) Africa and Americas have substantial numbers of countries, with approximately 48 and 36 countries, respectively. This            suggests that healthcare policies and interventions in these regions need to consider the diversity and unique                  challenges within each region.
#       c) The Eastern Mediterranean region has around 25 countries, indicating a moderate level of diversity and healthcare                considerations. Policies and interventions in this region may need to be tailored to the specific needs of these 25              countries.
#       d) Southeast Asia has the smallest number of countries among the specified regions, with around 15. This may suggest a              more focused approach to regional healthcare policies and interventions due to the relatively smaller number of                  countries.
#       e) The Western Pacific region has around 18 countries, which is in the middle range among the specified regions. This              indicates a moderate level of diversity and complexity in healthcare considerations for this region.
#
#       OBSERVATIONS:
#       a) The bar chart visually represents the distribution of countries across different WHO regions, highlighting the                  diversity in the number of countries in each region.
#       b) Regions with a higher number of countries may pose management complexities in terms of coordinating healthcare                  policies, resource allocation, and implementing interventions.
#       c) The data underscores the importance of tailoring healthcare approaches to suit the unique needs and challenges within            each WHO region.
#       d) The varying counts present opportunities for global collaboration, knowledge exchange, and joint efforts to address              common health challenges.
#
#       INSIGHTS AND MANAGERIAL IMPLICATIONS:
#       a) The diversity in the number of countries across regions implies diverse healthcare needs, challenges, and priorities.            Healthcare policies and interventions should be tailored to the specific requirements of each region.
#       b) Regions with a higher number of countries may require more extensive resource allocation for healthcare infrastructure,          disease prevention, and public health programs. Europe, with the largest number, might need substantial resources for            healthcare management.
#       c) Given the diverse healthcare landscapes, there is a need for collaboration and information sharing among countries              within each region. This could facilitate the exchange of best practices, resources, and expertise to address common            health issues.
#       d) Regions with a smaller number of countries, such as Southeast Asia, may benefit from more tailored and localized                healthcare strategies, considering the unique characteristics of each country.
#       e) The variations in the number of countries across regions highlight the importance of a global perspective in health              policymaking. Collaborative efforts on a global scale can help address cross-border health challenges and promote a              more coordinated response.
#
#    2. PIE CHART SHOWING PERCENTAGE OF CASES IN EACH WHO REGION :
#       The pie chart illustrates the percentage distribution of cases in each WHO region based on the provided data.It aims to         visually represent the proportion of cases contributed by each WHO region, providing a quick overview of the global             distribution of health burdens.
#
#       ANALYSIS :
#       a) Europe contributes the highest percentage of cases among all WHO regions.This suggests a considerable health burden in          European countries, possibly influenced by factors such as population density, lifestyle, and prevalent health issues.
#       b) South-East Asia has the smallest percentage of cases.The region exhibits a relatively lower health burden, indicating            effective healthcare measures, lower disease prevalence, or successful public health interventions.
#       c) The Western Pacific region contributes a moderate percentage of cases.This suggests a balanced health burden in this            region, requiring attention to specific health challenges but not as pronounced as in other regions
#       d) Eastern Mediterranean has a substantial percentage of cases.The region faces a noteworthy health burden, indicating the          prevalence of specific health issues that may require targeted interventions and research.
#       e) he Americas exhibit a significant contribution to the total cases.Diverse health challenges across North and South              America contribute to a substantial health burden, necessitating prioritized resource allocation and cross-border                collaboration.
#       f) Africa has the second-highest percentage of cases.The continent faces a notable health burden, possibly influenced by            unique socio-economic factors and a diverse range of health challenges.
#
#       OBSERVATIONS :
#       a) There are clear disparities in health burdens among regions, emphasizing the need for region-specific healthcare                strategies and interventions.
#       b) The Americas and Africa stand out with substantial percentages, suggesting a complex health landscape. This complexity          may be influenced by diverse socio-economic factors, geographic variations, and a range of prevalent diseases.
#       c) Policymakers may consider prioritizing resource allocation based on the observed percentages. Regions with higher                percentages demand more extensive resources and targeted interventions.
#       d) The varying health burdens provide opportunities for collaboration, knowledge sharing, and joint efforts to address              common health challenges globally.
#       e) The diverse percentages highlight the importance of tailoring healthcare strategies to the specific needs and                    challenges of each region, promoting effective and targeted interventions.
#
#       INSIGHIS AND MANAGERIAL IMPLICATIONS :
#       a) Allocate resources proportionate to the percentage of cases in each region and Prioritize regions with higher                    percentages for more extensive resource allocation.
#       b) Develop region-specific interventions based on prevalent health challenges and Customize healthcare strategies to                address the unique needs of each region.
#       c) Prioritize research efforts in regions with higher percentages to understand underlying factors and Facilitate                  collaboration among regions for shared learning, resource sharing, and effective global health strategies.
#       d) Design targeted public health campaigns to address prevalent health issues in each region and Tailor campaigns based on          the specific challenges and needs identified in the analysis.
#       e) Strive for global health equity by addressing disparities and ensuring access to quality healthcare across regions and          Implement policies that promote inclusivity and equal access to healthcare resources.
#
#    3. LINE CHART SHOWNG NUMBER OF NEW CASES:
#       The bar chart represents the number of new cases in each WHO region, providing a visual overview of the distribution of         reported cases across different geographic areas.The analysis of the chart allows for a comparative assessment of the           severity of new cases across regions, aiding in strategic decision-making and collaborative efforts to address global           health concerns.
#
#       ANALYSIS :
#       a) Europe shows the highest number of new cases.This suggests a significant ongoing or emerging health challenge within            European countries, necessitating focused attention and interventions
#       b) Africa has a comparatively lower number of new cases.The lower count may indicate either effective containment                  measures, a lower prevalence of the disease, or reporting/testing variations.
#       c) Americas exhibit a substantial number of new cases.A significant count in the Americas indicates a considerable health          burden, demanding robust public health responses.
#       d) Eastern Mediterranean has a moderate count of new cases.This suggests a moderate level of ongoing health challenges in          the region, requiring attention but possibly not as severe as in some other regions.
#       e) Southeast Asia shows a lower number of new cases.The relatively lower count may signify successful control measures or          a lesser impact of the health issue in this region.
#       f) Western Pacific has a moderate count of new cases.A moderate count indicates an ongoing health concern that requires            attention but might not be as acute as in other regions.
#
#       OBSERVATIONS:
#       a) The line chart provides a snapshot of the current distribution of new cases across different WHO regions, emphasizing            the need for adaptive and region-specific public health strategies.
#       b) High counts in Europe and the Americas warrant immediate attention, while lower counts in Southeast Asia suggest the            potential effectiveness of control measures.
#       c) Ongoing monitoring and collaboration can help address emerging health challenges effectively and facilitate a                    coordinated global response.
#
#       INSIGHTS AND MANAGERIAL IMPLICATIONS:
#       a) Regions with higher new case counts, such as Europe and the Americas, may require a prioritized allocation of resources          for healthcare infrastructure, testing, and treatment.
#       b) Tailoring interventions based on regional new case counts is essential. High-count regions might need more aggressive            public health measures.
#       c) Regions with lower new case counts, like Southeast Asia, could be studied for successful containment strategies and              preventive measures.
#       d) Collaborative efforts are crucial to share best practices, resources, and knowledge, especially between regions facing          similar challenges.
#
#    4. PIE CHART SHOWING RECOVERY PERCENTAGE OF EACH REGION :
#       The presented pie chart visually encapsulates the distribution of recovery percentages across various WHO regions. Each         segment represents the proportion of recovered cases relative to the total cases reported in a specific region. The chart       aims to offer a comparative insight into the recovery rates, allowing for the identification of regions with notable             success in managing and recovering from cases.
#
#       ANALYSIS :
#       a) The pie chart reveals that Europe has the highest percentage of recovered cases among the specified WHO regions,                constituting 21.06%. This suggests a notable success in managing and recovering from cases in European countries.
#       b) The Americas region also makes a substantial contribution, with 47.20% of recovered cases. This indicates a                      considerable achievement in recovery efforts in North and South American countries.
#       c) Eastern Mediterranean (12.69%), South-East Asia (12.22%), and Africa (4.65%) exhibit moderate percentages, suggesting a          balanced distribution of recovery rates across these regions.
#       d) The Western Pacific region has the lowest recovery percentage at 2.18%. While this may indicate challenges in recovery          efforts in this region, it's essential to consider the overall context.
#
#       OVSERVATIONS :
#       a) The pie chart illustrates diversity in recovery outcomes across WHO regions, emphasizing the need for context-specific          approaches to managing and overcoming health challenges.
#       b) Managing recovery efforts involves addressing region-specific factors, and the varying percentages highlight the                complexity of healthcare management on a global scale.
#       c) The disparities in recovery rates present opportunities for global collaboration, where regions with higher success              rates can support others in improving their recovery strategies.
#       d) The recovery percentages indicate the effectiveness of ongoing strategies, but continuous monitoring and adaptation are          essential to address evolving health scenarios and emerging challenges.
#
#       INSIGHTS AND MANAGERIAL IMPLICATIONS :
#       a) Policymakers can use the recovery rate distribution to allocate resources effectively. Regions with higher recovery              percentages may need to maintain their successful strategies, while those with lower percentages may require additional          support.
#       b) The data highlights success stories in recovery efforts, such as Europe and the Americas. Analyzing the factors                  contributing to these successes can inform best practices for other regions.
#       c) Understanding regional differences in recovery rates allows for the development of tailored strategies to address                specific challenges and capitalize on strengths in each WHO region.
#       d) Regions with higher recovery percentages can collaborate with those facing challenges, fostering a global learning              environment where successful strategies can be shared and adapted.
#
#    5. CHART SHOWING REGION WISE ACTIVE CASES :
#       The vertical bar chart illustrates the regional distribution of active COVID-19 cases, revealing distinct patterns across       WHO regions. Europe bears the heaviest burden with 1,094,656 active cases, indicative of a significant and ongoing impact.       The Americas closely trail, reporting 4,027,938 active cases, emphasizing the substantial presence of the virus in North         and South America. South-East Asia follows suit with 637,015 cases, signaling a notable viral presence in the region.
#
#       ANALYSIS :
#       a) The pie chart illustrates that Europe has the highest percentage of total cases among the specified WHO regions. This            suggests a substantial burden of health issues or a larger population in the European region.
#       b) The Americas region also makes a substantial contribution to the total cases, indicating a considerable burden of                health challenges or diseases in this region.
#       c) Eastern Mediterranean, Africa, and Western Pacific regions show moderate percentages, suggesting a more balanced                distribution of cases across these regions.
#       d) South-East Asia has the smallest percentage, indicating a relatively lower burden of cases compared to other regions.
#
#       OBSERVATIONS :
#       a) The pie chart visually represents the distribution of cases across different WHO regions, emphasizing the diversity in          the impact of health challenges.
#       b) Regions with varying case percentages may pose management complexities in coordinating healthcare policies, resource            allocation, and implementing interventions.
#       c) The data underscores the importance of tailoring healthcare approaches to suit the unique needs and challenges within            each WHO region.
#       d) The varying percentages present opportunities for global collaboration, knowledge exchange, and joint effort to
#          address common health challenges on an international scale.
#
#       INSIGHTS AND MANAGERIAL IMPLICATIONS :
#       a) Policymakers can utilize this information to allocate resources proportionate to the percentage distribution of cases.          Regions with higher percentages may require more extensive healthcare infrastructure and interventions.
#       b) Tailored interventions can be designed based on the specific health challenges prevalent in each region. Understanding          the distribution helps prioritize and address the most significant health issues.
#       c) Regions with higher percentages can collaborate with international organizations and other regions to share best                practices, resources, and expertise. This collaborative approach can enhance the effectiveness of health interventions.
#       d) The regions with higher percentages may attract more attention from researchers and policymakers for in-depth studies            and interventions. This can contribute to a better understanding of the factors influencing health outcomes.
#       e) The distribution of cases can guide the development of public health campaigns that target specific regions or issues.          Tailoring campaigns to regional needs can increase their effectiveness.
#       f) Understanding the distribution of cases highlights the importance of addressing global health equity. Efforts should be          made to reduce disparities in healthcare access and outcomes across different regions.
#
#    5.MANAGERIAL IMPLICATIONS :
#    a)  Allocate resources based on the severity and prevalence of COVID-19 cases in each WHO region.
#    b)  Implement region-specific interventions considering the unique challenges and characteristics of each WHO region.
#    c)  Facilitate collaboration among regions, international organizations, and research institutions to share best practices,          resources, and expertise.
#    d)  Prioritize research efforts in regions with higher percentages of cases for in-depth studies and better understanding of        factors influencing health outcomes.
#    e)  Address disparities in healthcare access and outcomes across different regions to promote global health equity.
#    f)  Enhance public health preparedness and response mechanisms to effectively manage and mitigate the impact of future health        crises.
#    g)  Embrace adaptive management strategies to respond dynamically to evolving situations and changing healthcare landscapes.
#    h)  Strengthen international cooperation and coordination for a unified global response to health crises.
#
#    6.RECOMMENDATIONS :
#    a)  Prioritize regions with higher active cases for resource-intensive interventions, healthcare infrastructure, and medical        supplies.
#    b)  Develop targeted public health campaigns, treatment protocols, and preventive measures tailored to the specific needs of        each region.
#    c)  Encourage cross-border collaboration to strengthen global response efforts, promote knowledge exchange, and address              common health challenges collectively.
#    d)  Invest in comprehensive data collection, analysis, and research to inform evidence-based decision-making, identify              emerging challenges, and guide long-term strategies.
#    e)  Advocate for policies and initiatives that ensure equitable distribution of healthcare resources, vaccines, and medical          interventions globally.
#    f)  Develop robust public health infrastructure, early warning systems, and collaborative frameworks to respond swiftly to          emerging health threats.
#    g)  Establish flexible and responsive management frameworks that can adapt to the unique challenges presented by different          regions, considering variations in healthcare systems, socio-economic factors, and population density.
#    h)  Engage in diplomatic efforts to foster collaboration, share resources, and ensure a coordinated global approach to              address shared health challenges.
#
#      REFERENCE : FEW CODES FROM CHATGPT
